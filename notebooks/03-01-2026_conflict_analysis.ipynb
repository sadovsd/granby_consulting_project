# %% [markdown]
# Gettman & Head (2003) — the original SSAM developers at FHWA showed correlation between simulated conflict counts and observed crash data
#
# Essa & Sayed (multiple papers, 2010s-2020s) — some of the best recent work specifically validating that SSAM-derived conflict measures correlate with real crash data, including for pedestrians
